# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df_raport = pd.read_csv('../testing/raport.csv', names=['operations'])
df_raport.head()
# Out:
#    operations
# 0        1400
# 1       47104
# 2       17457
# 3         768
# 4         360

# %%
df_times = pd.read_csv('../time_raport.csv', names=['time'])
# to milisecs
df_times['time'] = df_times.time * 1000
df_times['time'] = df_times.time * df_times.time * df_times.time
df_times.head()
# Out:
#            time
# 0   7909.146121
# 1  18216.359203
# 2   9807.215005
# 3   4329.949979
# 4   1693.669888

# %%
frames = [df_raport, df_times]
df_full_raport = pd.concat(frames, axis = 1, sort = False)

# %%
df_full_raport.sort_values("operations", ascending = True)
# Out:
#     operations           time
# 8          128     136.272852
# 10         128     171.231247
# 22         128     120.700265
# 69         128     123.134359
# 4          360    1693.669888
# 78         588     305.501115
# 13         588     254.960710
# 6          637     232.041499
# 3          768    4329.949979
# 5          768    5419.315837
# 62         896    1946.102184
# 98        1215    2365.396076
# 11        1215    2377.666733
# 0         1400    7909.146121
# 16        1600    3070.120825
# 41        1600     665.567282
# 36        2057    6798.530576
# 24        2057    6734.137431
# 49        2448   10444.577343
# 37        3042   10681.430926
# 57        3724   16522.921323
# 23        3920    6659.527537
# 47        4312    3547.973683
# 68        4725   24487.529386
# 99        4950   10235.274416
# 46        5175    8372.846813
# 84        5175    9066.572710
# 64        5376   22282.929144
# 72        5632   17213.481368
# 9         6656     875.094437
# ..         ...            ...
# 1        47104   18216.359203
# 54       60025   34135.193821
# 75       61250   17059.938847
# 15       62475   14521.426419
# 61       64343  104187.911691
# 85       64800   66179.482639
# 93       69819   47871.688591
# 73       69819  107016.269120
# 74       72557   26503.573918
# 91       75088   63044.792000
# 65       75088   62537.680946
# 40       82134  101357.650391
# 45       88000   43324.914636
# 53       90774   30667.236164
# 21       93492   84177.399164
# 55       98784  164449.501221
# 32      105393   61629.875000
# 80      110940   90918.606021
# 51      112288  225077.473103
# 92      114224  124072.304493
# 39      119475  115814.649015
# 38      121500  145075.537779
# 26      130331  187090.361057
# 34      140544  203214.504729
# 48      141376  194990.921054
# 82      166464  184326.870786
# 17      181168  222313.737485
# 81      188203  135662.048599
# 77      245572  258036.870099
# 28      286517  299230.372714
#
# [100 rows x 2 columns]

# %%
X = df_full_raport.iloc[:, 0].values.reshape(-1, 1)
Y = df_full_raport.iloc[:, 1].values.reshape(-1, 1) 

linear_regressor = LinearRegression()
linear_regressor.fit(X, Y)
Y_pred = linear_regressor.predict(X)  

plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.rcParams["figure.figsize"] = (20,20)
plt.show()
