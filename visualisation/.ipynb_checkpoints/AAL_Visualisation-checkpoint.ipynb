# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df_raport = pd.read_csv('raport.csv', names=['operations'])
df_raport['operations'] = df_raport**(0.3333333)
df_raport.head()
# Out:
#    operations
# 0   38.664208
# 1   38.141655
# 2   46.676652
# 3   51.546078
# 4   34.302366

# %%
df_times = pd.read_csv('time_raport.csv', names=['time'])
# to milisecs
df_times['time'] = df_times.time * 1000
df_times.head()
# Out:
#       time
# 0  100.502
# 1  106.666
# 2  167.782
# 3  152.075
# 4  137.792

# %%
frames = [df_raport, df_times]
df_full_raport = pd.concat(frames, axis = 1, sort = False)

# %%
df_full_raport.sort_values("operations", ascending = True)
# Out:
#      operations     time
# 189    5.039683   16.594
# 16     5.039683   18.163
# 110    5.039683   16.230
# 238    5.039683   18.130
# 196    8.377717   21.953
# 33     8.377717   26.901
# 207    8.377717   22.371
# 165    8.604251   26.031
# 104    8.604251   23.531
# 138    9.157712   35.297
# 10     9.640567   43.879
# 161    9.640567   42.151
# 36    11.186887   48.347
# 49    11.447140   36.868
# 176   11.447140   38.418
# 169   11.696068   24.448
# 155   11.934829   27.846
# 82    11.934829   25.919
# 45    12.164401   28.037
# 154   12.463356   38.644
# 32    12.717780   50.857
# 66    13.207706   43.044
# 73    13.477325   49.990
# 129   13.736567   52.583
# 69    13.736567   52.525
# 80    13.736567   44.412
# 149   13.736567   52.885
# 132   13.986378   52.500
# 20    13.986378   50.303
# 40    13.986378   51.192
# ..          ...      ...
# 28    67.648533  251.971
# 209   68.055865  240.080
# 27    68.941881  256.058
# 174   69.064183  206.384
# 95    69.340443  221.955
# 241   70.952394  259.202
# 89    71.524616  280.496
# 245   72.087825  217.855
# 14    72.530832  241.146
# 29    74.542787  239.810
# 134   74.680087  255.615
# 137   75.684137  165.491
# 93    77.098844  176.786
# 215   78.851688  318.345
# 234   79.570160  281.534
# 48    81.148753  287.812
# 158   81.868482  306.156
# 112   82.294266  158.434
# 51    83.298544  216.665
# 65    83.589800  351.574
# 180   83.879041  323.426
# 25    84.166300  293.274
# 216   84.302725  180.874
# 42    88.023155  189.179
# 183   90.912486  328.926
# 235   91.329521  344.316
# 159   91.491562  330.098
# 13    94.506951  390.114
# 67   100.952517  339.927
# 222  104.258431  337.395
#
# [250 rows x 2 columns]

# %%
X = df_full_raport.iloc[:, 0].values.reshape(-1, 1)
Y = df_full_raport.iloc[:, 1].values.reshape(-1, 1) 

# linear_regressor = LinearRegression()
# linear_regressor.fit(X, Y)
# Y_pred = linear_regressor.predict(X)  

plt.scatter(X, Y)
# plt.plot(X, Y_pred, color='red')
plt.rcParams["figure.figsize"] = (20,20)
plt.show()
