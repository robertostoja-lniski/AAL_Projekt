# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df_raport = pd.read_csv('raport.csv', names=['operations'])
df_raport.head()
# Out:
#    operations
# 0       57800
# 1       55488
# 2      101695
# 3      136958
# 4       40362

# %%
df_times = pd.read_csv('time_raport.csv', names=['time'])
# to milisecs
df_times['time'] = df_times.time * 1000
df_times['time'] = df_times.time * df_times.time * df_times.time
df_times.head()
# Out:
#            time
# 0  1.015136e+06
# 1  1.213607e+06
# 2  4.723197e+06
# 3  3.517009e+06
# 4  2.616206e+06

# %%
frames = [df_raport, df_times]
df_full_raport = pd.concat(frames, axis = 1, sort = False)

# %%
df_full_raport.sort_values("operations", ascending = True)
# Out:
#      operations          time
# 189         128  4.569338e+03
# 16          128  5.991875e+03
# 110         128  4.275191e+03
# 238         128  5.959275e+03
# 196         588  1.057990e+04
# 33          588  1.946728e+04
# 207         588  1.119583e+04
# 165         637  1.763894e+04
# 104         637  1.302930e+04
# 138         768  4.397576e+04
# 10          896  8.448316e+04
# 161         896  7.488997e+04
# 36         1400  1.130078e+05
# 49         1500  5.011281e+04
# 176        1500  5.670277e+04
# 169        1600  1.461268e+04
# 155        1700  2.159178e+04
# 82         1700  1.741224e+04
# 45         1800  2.203914e+04
# 154        1936  5.770935e+04
# 32         2057  1.315383e+05
# 66         2304  7.975132e+04
# 73         2448  1.249250e+05
# 129        2592  1.453905e+05
# 69         2592  1.449099e+05
# 80         2592  8.759937e+04
# 149        2592  1.479100e+05
# 132        2736  1.447031e+05
# 20         2736  1.272863e+05
# 40         2736  1.341548e+05
# ...

# %%
X = df_full_raport.iloc[:, 0].values.reshape(-1, 1)
Y = df_full_raport.iloc[:, 1].values.reshape(-1, 1) 

linear_regressor = LinearRegression()
linear_regressor.fit(X, Y)
Y_pred = linear_regressor.predict(X)  

plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.rcParams["figure.figsize"] = (20,20)
plt.show()
